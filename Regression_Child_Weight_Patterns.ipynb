# %% [markdown]
# <a href="https://colab.research.google.com/github/SiddharthPatel2005/BMI_FOR-CHILDREN/blob/main/Regression_Child_Weight_Patterns.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import statsmodels.formula.api as smf
import statsmodels.api as sm
import warnings
warnings.filterwarnings("ignore")

df = pd.read_csv("/content/BMIData.csv")

print(df.head())
print(df.info())
print(df.describe())
# Out:
#    SchoolYear NameHospital     Sex  EpiUnderweight  EpiHealthyWeight  \
# 0        2001      Borders  Female               2               334
# 1        2001      Borders    Male               5               301
# 2        2001      Lothian  Female              12               728
# 3        2001      Lothian    Male              17               681
# 4        2001         Fife  Female              17              1361
#
#    EpiOverweight  EpiObese  EpiOverweightAndObese  ValidCounts  UnvalidCounts  \
# 0             54        28                     82          418             82
# 1             63        42                    105          411            105
# 2            133       106                    239          979            239
# 3            124       114                    238          936            238
# 4            231       155                    386         1764            386
#
#    TotalCounts
# 0          500
# 1          516
# 2         1218
# 3         1174
# 4         2150
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 516 entries, 0 to 515
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   SchoolYear             516 non-null    int64
#  1   NameHospital           516 non-null    object
#  2   Sex                    516 non-null    object
#  3   EpiUnderweight         516 non-null    int64
#  4   EpiHealthyWeight       516 non-null    int64
#  5   EpiOverweight          516 non-null    int64
#  6   EpiObese               516 non-null    int64
#  7   EpiOverweightAndObese  516 non-null    int64
#  8   ValidCounts            516 non-null    int64
#  9   UnvalidCounts          516 non-null    int64
#  10  TotalCounts            516 non-null    int64
# dtypes: int64(9), object(2)
# memory usage: 44.5+ KB
# None
#         SchoolYear  EpiUnderweight  EpiHealthyWeight  EpiOverweight  \
# count   516.000000      516.000000         516.00000     516.000000
# mean   2013.383721       21.742248        1304.72093     208.102713
# std       5.947672       25.207054        1103.90967     167.192486
# min    2001.000000        0.000000           7.00000       0.000000
# 25%    2009.000000        3.000000         421.75000      66.750000
# 50%    2013.500000       13.000000        1158.50000     196.000000
# 75%    2018.000000       30.000000        1946.25000     292.000000
# max    2023.000000      137.000000        4623.00000     696.000000
#
#          EpiObese  EpiOverweightAndObese  ValidCounts  UnvalidCounts  \
# count  516.000000             516.000000   516.000000     516.000000
# mean   175.563953             383.666667  1710.129845     383.666667
# std    147.842378             313.523071  1433.191567     313.523071
# min      2.000000               2.000000    10.000000       2.000000
# 25%     52.000000             120.500000   549.000000     120.500000
# 50%    160.500000             350.500000  1558.500000     350.500000
# 75%    243.000000             537.000000  2523.250000     537.000000
# max    737.000000            1433.000000  6150.000000    1433.000000
#
#        TotalCounts
# count   516.000000
# mean   2093.796512
# std    1743.889989
# min      12.000000
# 25%     669.500000
# 50%    1904.500000
# 75%    3038.750000
# max    7583.000000

# %%
print(df.isnull().sum())
numeric_cols = df.select_dtypes(include=[np.number]).columns
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].median())

# %%
print("Duplicate rows:", df.duplicated().sum())
df = df.drop_duplicates()

# %%
# Create new columns for proportions based on ValidCounts
df['PropUnderweight'] = df['EpiUnderweight'] / df['ValidCounts']
df['PropHealthyWeight'] = df['EpiHealthyWeight'] / df['ValidCounts']
df['PropOverweight'] = df['EpiOverweight'] / df['ValidCounts']
df['PropObese'] = df['EpiObese'] / df['ValidCounts']
df['PropOverweightAndObese'] = df['EpiOverweightAndObese'] / df['ValidCounts']
print(df[['PropUnderweight', 'PropHealthyWeight', 'PropOverweight', 'PropObese', 'PropOverweightAndObese']].head())
# Out:
#    PropUnderweight  PropHealthyWeight  PropOverweight  PropObese  \
# 0         0.004785           0.799043        0.129187   0.066986
# 1         0.012165           0.732360        0.153285   0.102190
# 2         0.012257           0.743616        0.135853   0.108274
# 3         0.018162           0.727564        0.132479   0.121795
# 4         0.009637           0.771542        0.130952   0.087868
#
#    PropOverweightAndObese
# 0                0.196172
# 1                0.255474
# 2                0.244127
# 3                0.254274
# 4                0.218821

# %% [markdown]
# These new columns allow you to compare hospitals on a common scale, regardless of how many children they serve.

# %% [markdown]
# ## Step 4: Exploratory Data Analysis (EDA) – Summary Statistics

# %%
print(df[['PropUnderweight', 'PropHealthyWeight', 'PropOverweight', 'PropObese']].describe())
# Out:
#        PropUnderweight  PropHealthyWeight  PropOverweight   PropObese
# count       516.000000         516.000000      516.000000  516.000000
# mean          0.011183           0.757434        0.125710    0.105673
# std           0.007941           0.031983        0.020968    0.021884
# min           0.000000           0.583333        0.000000    0.046875
# 25%           0.005970           0.744919        0.114445    0.092561
# 50%           0.009811           0.761176        0.123808    0.101467
# 75%           0.014950           0.776438        0.135451    0.114766
# max           0.050000           0.840708        0.244898    0.250000

# %%
df[['PropUnderweight', 'PropHealthyWeight', 'PropOverweight', 'PropObese']].hist(bins=20, figsize=(12, 8), edgecolor='black')
plt.suptitle("Distribution of BMI Proportions")
plt.show()

# %% [markdown]
# This helps you see the average trends and differences in the BMI categories. The histo show that most kids (70–80%) are at a healthy weight across hospitals, while around 10% are overweight and another 10% are obese. Very few kids (0–2%) are underweight. This pattern highlights the issue of overweight and obesity, especially in hospitals where these numbers are much higher than usual.

# %% [markdown]
# ## Step 5: Analyze Trends Over Time (SchoolYear)

# %%
yearly_trends = df.groupby('SchoolYear')[['PropUnderweight', 'PropHealthyWeight', 'PropOverweight', 'PropObese']].mean().reset_index()
print(yearly_trends)
# Out:
#     SchoolYear  PropUnderweight  PropHealthyWeight  PropOverweight  PropObese
# 0         2001         0.014237           0.755882        0.130036   0.099844
# 1         2002         0.016210           0.748644        0.130714   0.104432
# 2         2003         0.012998           0.758594        0.130420   0.097988
# 3         2004         0.012765           0.742699        0.122960   0.121576
# 4         2005         0.012955           0.750621        0.130682   0.105742
# 5         2006         0.014303           0.764450        0.120995   0.100253
# 6         2007         0.016162           0.771667        0.118039   0.094132
# 7         2008         0.017211           0.773590        0.115641   0.093558
# 8         2009         0.013772           0.761248        0.121190   0.103790
# 9         2010         0.014889           0.761986        0.123864   0.099261
# 10        2011         0.010902           0.760933        0.125219   0.102946
# 11        2012         0.010541           0.769212        0.119813   0.100433
# 12        2013         0.009514           0.755249        0.129242   0.105996
# 13        2014         0.008523           0.761657        0.126016   0.103804
# 14        2015         0.008858           0.765697        0.125420   0.100026
# 15        2016         0.007723           0.755939        0.128413   0.107924
# 16        2017         0.008314           0.759063        0.128308   0.104315
# 17        2018         0.008136           0.755003        0.129367   0.107493
# 18        2019         0.007891           0.753314        0.134141   0.104654
# 19        2020         0.010595           0.698768        0.134929   0.155707
# 20        2021         0.009515           0.744283        0.128071   0.118131
# 21        2022         0.010181           0.760467        0.121638   0.107714
# 22        2023         0.011717           0.753640        0.127709   0.106935

# %%
plt.figure(figsize=(10, 6))
for col in ['PropUnderweight', 'PropHealthyWeight', 'PropOverweight', 'PropObese']:
    sns.lineplot(data=yearly_trends, x='SchoolYear', y=col, marker='o', label=col)

plt.xticks(rotation=45)
plt.title("BMI Proportion Trends Over School Years")
plt.xlabel("School Year")
plt.ylabel("Average Proportion")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# BMI categories proportions change over time.

# %% [markdown]
# ## Step 6: Compare Hospitals

# %%
hospital_summary = df.groupby('NameHospital')[['PropUnderweight', 'PropHealthyWeight', 'PropOverweight', 'PropObese']].mean().reset_index()
print(hospital_summary.head())
# Out:
#             NameHospital  PropUnderweight  PropHealthyWeight  PropOverweight  \
# 0     Ayrshire and Arran         0.013475           0.744227        0.128681
# 1                Borders         0.008409           0.772596        0.125012
# 2  Dumfries and Galloway         0.007731           0.742292        0.137032
# 3                   Fife         0.009044           0.758541        0.127450
# 4           Forth Valley         0.010546           0.776265        0.119511
#
#    PropObese
# 0   0.113617
# 1   0.093983
# 2   0.112945
# 3   0.104966
# 4   0.093678

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=hospital_summary, x='PropObese', y='NameHospital', palette='viridis')
plt.title("Average Proportion of Obese Children by Hospital")
plt.xlabel("Proportion Obese")
plt.ylabel("Hospital")
plt.tight_layout()
plt.show()

hospital_heatmap = hospital_summary.set_index('NameHospital')
plt.figure(figsize=(12, 10))
sns.heatmap(hospital_heatmap, annot=True, cmap="YlGnBu", fmt=".2f")
plt.title("BMI Proportions by Hospital")
plt.ylabel("Hospital")
plt.show()

# %% [markdown]
# This compares how different hospitals perform in terms of BMI categories distributions.

# %% [markdown]
# ## Step 7: Compare by Gender

# %%
gender_summary = df.groupby('Sex')[['PropUnderweight', 'PropHealthyWeight', 'PropOverweight', 'PropObese']].mean().reset_index()
print(gender_summary)
# Out:
#       Sex  PropUnderweight  PropHealthyWeight  PropOverweight  PropObese
# 0  Female         0.008608           0.766216        0.124067   0.101109
# 1    Male         0.013758           0.748652        0.127353   0.110238

# %%
gender_summary_melted = gender_summary.melt(id_vars='Sex', var_name='BMI_Category', value_name='Average_Proportion')

plt.figure(figsize=(8, 6))
sns.barplot(data=gender_summary_melted, x='Sex', y='Average_Proportion', hue='BMI_Category', palette='viridis')
plt.title("BMI Proportions by Gender")
plt.ylabel("Average Proportion")
plt.show()

# %% [markdown]
# Highlights any gender-based differences in BMI categories distributions.

# %% [markdown]
# ## Step 8: Create Pivot Tables for Quick Comparison

# %%
pivot = pd.pivot_table(
    df,
    index='NameHospital',
    columns='SchoolYear',
    values=['PropUnderweight', 'PropHealthyWeight', 'PropOverweight', 'PropObese'],
    aggfunc='mean'
)
print(pivot)
# Out:
#                           PropHealthyWeight                                \
# SchoolYear                             2001      2002      2003      2004
# NameHospital
# Ayrshire and Arran                      NaN       NaN       NaN       NaN
# Borders                            0.765702       NaN  0.762698  0.734882
# Dumfries and Galloway                   NaN       NaN       NaN  0.741763
# Fife                               0.754291  0.748538  0.749290  0.746864
# Forth Valley                            NaN       NaN       NaN       NaN
# Grampian                                NaN       NaN       NaN       NaN
# Greater Glasgow and Clyde               NaN       NaN       NaN       NaN
# Highland                                NaN       NaN       NaN       NaN
# Lanarkshire                        0.767947  0.764356  0.748501  0.761026
# Lothian                            0.735590  0.715051  0.763816  0.751594
# Orkney                                  NaN       NaN       NaN       NaN
# Shetland                                NaN       NaN       NaN       NaN
# Tayside                                 NaN  0.766630  0.758475  0.771095
# Western Isles                           NaN       NaN  0.768780  0.691667
#
#                                                                              \
# SchoolYear                     2005      2006      2007      2008      2009
# NameHospital
# Ayrshire and Arran              NaN       NaN  0.762970  0.790614  0.754415
# Borders                    0.774600  0.778650  0.798154  0.777707  0.749924
# Dumfries and Galloway      0.755944  0.740752  0.749264  0.762014  0.740107
# Fife                       0.712269  0.739064  0.754805  0.774083  0.760919
# Forth Valley               0.754467  0.782134  0.800566  0.783753  0.771899
# Grampian                        NaN       NaN       NaN       NaN  0.781285
# Greater Glasgow and Clyde       NaN  0.768879  0.800598  0.810744  0.777570
# Highland                        NaN       NaN       NaN  0.739298  0.745857
# Lanarkshire                0.764178  0.772415  0.772267  0.788321  0.792131
# Lothian                    0.756610  0.748536  0.753249  0.759754  0.763933
# Orkney                          NaN       NaN       NaN       NaN       NaN
# Shetland                        NaN       NaN       NaN  0.789483  0.764092
# Tayside                    0.748345  0.763674  0.785068  0.761606  0.765186
# Western Isles              0.738553  0.785948  0.739731  0.745699  0.728902
#
#                                      ... PropUnderweight                      \
# SchoolYear                     2010  ...            2014      2015      2016
# NameHospital                         ...
# Ayrshire and Arran         0.725677  ...        0.012167  0.012046  0.013274
# Borders                    0.785869  ...        0.009860  0.007313  0.006233
# Dumfries and Galloway      0.755617  ...        0.000675  0.003609  0.005327
# Fife                       0.762007  ...        0.008151  0.007935  0.010645
# Forth Valley               0.790432  ...        0.007969  0.011843  0.004946
# Grampian                   0.787659  ...        0.009154  0.013647  0.006169
# Greater Glasgow and Clyde  0.803211  ...        0.014640  0.011551  0.011244
# Highland                   0.737046  ...        0.006506  0.008604  0.007013
# Lanarkshire                0.791863  ...        0.019470  0.017645  0.013012
# Lothian                    0.765770  ...        0.009028  0.011339  0.011533
# Orkney                     0.740447  ...        0.000000  0.000000  0.005102
# Shetland                   0.771420  ...        0.000000  0.007398  0.004000
# Tayside                    0.739473  ...        0.007242  0.007728  0.005871
# Western Isles              0.711315  ...        0.014464  0.003356  0.003759
#
#                                                                              \
# SchoolYear                     2017      2018      2019      2020      2021
# NameHospital
# Ayrshire and Arran         0.014204  0.014591  0.011321  0.012792  0.013011
# Borders                    0.005412  0.004188       NaN       NaN  0.010955
# Dumfries and Galloway      0.008077  0.006778  0.009010       NaN  0.007130
# Fife                       0.008182  0.010024  0.010204       NaN  0.015558
# Forth Valley               0.012196  0.009312  0.013614       NaN  0.007382
# Grampian                   0.006810  0.007318       NaN       NaN  0.010237
# Greater Glasgow and Clyde  0.011121  0.008249       NaN  0.006501  0.013944
# Highland                   0.008960  0.006473  0.009402  0.003455  0.007949
# Lanarkshire                0.016753  0.014631  0.009554       NaN  0.010851
# Lothian                    0.011212  0.010509  0.009923  0.007006  0.010179
# Orkney                     0.000000  0.000000  0.005882  0.010417  0.000000
# Shetland                   0.000000  0.004630  0.000000  0.012195  0.007576
# Tayside                    0.009558  0.007944       NaN       NaN  0.010309
# Western Isles              0.003906  0.009259  0.000000  0.021800  0.008130
#
#
# SchoolYear                     2022      2023
# NameHospital
# Ayrshire and Arran         0.008313  0.009619
# Borders                    0.012776  0.006684
# Dumfries and Galloway      0.008666  0.013690
# Fife                       0.010847  0.010768
# Forth Valley               0.011157  0.026992
# Grampian                   0.011404  0.006511
# Greater Glasgow and Clyde  0.016002  0.011311
# Highland                   0.011639  0.008362
# Lanarkshire                0.008193  0.007448
# Lothian                    0.018613  0.019416
# Orkney                     0.000000  0.005102
# Shetland                   0.015000  0.018343
# Tayside                    0.009931  0.007747
# Western Isles              0.000000  0.012043
#
# [14 rows x 92 columns]

# %% [markdown]
# By creating matrix of our data we can reveal patterns across hospitals and years

# %% [markdown]
# ## A. Clustering

# %% [markdown]
# ## Step 1: Prepare the Data for Clustering

# %%
hospital_df = df.groupby('NameHospital').agg({
    'PropUnderweight': 'mean',
    'PropHealthyWeight': 'mean',
    'PropOverweight': 'mean',
    'PropObese': 'mean'
}).reset_index()
print(hospital_df.head())
# Out:
#             NameHospital  PropUnderweight  PropHealthyWeight  PropOverweight  \
# 0     Ayrshire and Arran         0.013475           0.744227        0.128681
# 1                Borders         0.008409           0.772596        0.125012
# 2  Dumfries and Galloway         0.007731           0.742292        0.137032
# 3                   Fife         0.009044           0.758541        0.127450
# 4           Forth Valley         0.010546           0.776265        0.119511
#
#    PropObese
# 0   0.113617
# 1   0.093983
# 2   0.112945
# 3   0.104966
# 4   0.093678

# %% [markdown]
# ## Step 2: Standardize the Features

# %%
features = ['PropUnderweight', 'PropHealthyWeight', 'PropOverweight', 'PropObese']
X = hospital_df[features]
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ## Step 3: Determine the Optimal Number of Clusters

# %%
inertia = []
k_range = range(1, 11)
for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X_scaled)
    inertia.append(kmeans.inertia_)
plt.figure(figsize=(8, 4))
plt.plot(k_range, inertia, marker='o')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')
plt.title('Elbow Method For Optimal k')
plt.show()

# %% [markdown]
# ## Step 4: Apply K-Means Clustering

# %%
optimal_k = 3
kmeans = KMeans(n_clusters=optimal_k, random_state=42)
hospital_df['Cluster'] = kmeans.fit_predict(X_scaled)
print(hospital_df.head())
# Out:
#             NameHospital  PropUnderweight  PropHealthyWeight  PropOverweight  \
# 0     Ayrshire and Arran         0.013475           0.744227        0.128681
# 1                Borders         0.008409           0.772596        0.125012
# 2  Dumfries and Galloway         0.007731           0.742292        0.137032
# 3                   Fife         0.009044           0.758541        0.127450
# 4           Forth Valley         0.010546           0.776265        0.119511
#
#    PropObese  Cluster
# 0   0.113617        1
# 1   0.093983        0
# 2   0.112945        2
# 3   0.104966        0
# 4   0.093678        0

# %% [markdown]
# ## Step 5: Analyze and Visualize the Clusters

# %% [markdown]
# ## a. View Cluster Centers (in the standardized space)

# %%
print("Cluster Centers (Standardized):")
print(kmeans.cluster_centers_)
centers_original = scaler.inverse_transform(kmeans.cluster_centers_)
centers_df = pd.DataFrame(centers_original, columns=features)
print("Cluster Centers (Original Scale):")
print(centers_df)
# Out:
# Cluster Centers (Standardized):
# [[ 0.27277218  0.67064432 -0.53733425 -0.65457816]
#  [ 0.46421339 -1.06955053  0.10206212  1.41651882]
#  [-1.12779213 -1.29889926  1.54396135  1.0193886 ]]
# Cluster Centers (Original Scale):
#    PropUnderweight  PropHealthyWeight  PropOverweight  PropObese
# 0         0.011966           0.766883        0.121255   0.099896
# 1         0.012719           0.741425        0.127122   0.118733
# 2         0.006457           0.738070        0.140352   0.115121

# %% [markdown]
# ## b. Visualize Clusters Using PCA

# %%
# Reduce dimensions to 2 components for visualization
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)
# Add PCA components to the hospital dataframe
hospital_df['PCA1'] = X_pca[:, 0]
hospital_df['PCA2'] = X_pca[:, 1]
# Create a scatter plot of the clusters
plt.figure(figsize=(8, 6))
sns.scatterplot(x='PCA1', y='PCA2', hue='Cluster', data=hospital_df, palette='viridis', s=100)
plt.title('Hospital Clusters (PCA Visualization)')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.show()

# %% [markdown]
# ## c. Examine Cluster Profiles

# %%
cluster_summary = hospital_df.groupby('Cluster')[features].mean().reset_index()
print(cluster_summary)
# Out:
#    Cluster  PropUnderweight  PropHealthyWeight  PropOverweight  PropObese
# 0        0         0.011966           0.766883        0.121255   0.099896
# 1        1         0.012719           0.741425        0.127122   0.118733
# 2        2         0.006457           0.738070        0.140352   0.115121

# %%
print(df[['EpiObese', 'ValidCounts', 'PropObese']].head())
# Out:
#    EpiObese  ValidCounts  PropObese
# 0        28          418   0.066986
# 1        42          411   0.102190
# 2       106          979   0.108274
# 3       114          936   0.121795
# 4       155         1764   0.087868

# %%
df['SchoolYear'] = df['SchoolYear'].astype('category')
df['Sex'] = df['Sex'].astype('category')

# %%
formula = "PropObese ~ C(SchoolYear) + C(Sex)"
model_linear = smf.ols(formula=formula, data=df).fit()
print(model_linear.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              PropObese   R-squared:                       0.264
# Model:                            OLS   Adj. R-squared:                  0.229
# Method:                 Least Squares   F-statistic:                     7.667
# Date:                Fri, 28 Feb 2025   Prob (F-statistic):           2.43e-21
# Time:                        14:50:15   Log-Likelihood:                 1319.5
# No. Observations:                 516   AIC:                            -2591.
# Df Residuals:                     492   BIC:                            -2489.
# Df Model:                          23
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 0.0953      0.007     13.921      0.000       0.082       0.109
# C(SchoolYear)[T.2002]     0.0046      0.010      0.478      0.633      -0.014       0.023
# C(SchoolYear)[T.2003]    -0.0019      0.009     -0.212      0.832      -0.019       0.015
# C(SchoolYear)[T.2004]     0.0217      0.009      2.553      0.011       0.005       0.038
# C(SchoolYear)[T.2005]     0.0059      0.008      0.709      0.479      -0.010       0.022
# C(SchoolYear)[T.2006]     0.0004      0.008      0.050      0.960      -0.016       0.016
# C(SchoolYear)[T.2007]    -0.0057      0.008     -0.711      0.478      -0.022       0.010
# C(SchoolYear)[T.2008]    -0.0063      0.008     -0.802      0.423      -0.022       0.009
# C(SchoolYear)[T.2009]     0.0039      0.008      0.508      0.612      -0.011       0.019
# C(SchoolYear)[T.2010]    -0.0006      0.008     -0.076      0.940      -0.016       0.015
# C(SchoolYear)[T.2011]     0.0031      0.008      0.403      0.687      -0.012       0.018
# C(SchoolYear)[T.2012]     0.0006      0.008      0.076      0.939      -0.015       0.016
# C(SchoolYear)[T.2013]     0.0062      0.008      0.799      0.425      -0.009       0.021
# C(SchoolYear)[T.2014]     0.0040      0.008      0.514      0.607      -0.011       0.019
# C(SchoolYear)[T.2015]     0.0002      0.008      0.024      0.981      -0.015       0.015
# C(SchoolYear)[T.2016]     0.0081      0.008      1.049      0.295      -0.007       0.023
# C(SchoolYear)[T.2017]     0.0045      0.008      0.581      0.562      -0.011       0.020
# C(SchoolYear)[T.2018]     0.0076      0.008      0.993      0.321      -0.007       0.023
# C(SchoolYear)[T.2019]     0.0048      0.008      0.599      0.550      -0.011       0.021
# C(SchoolYear)[T.2020]     0.0559      0.009      6.561      0.000       0.039       0.073
# C(SchoolYear)[T.2021]     0.0183      0.008      2.375      0.018       0.003       0.033
# C(SchoolYear)[T.2022]     0.0079      0.008      1.022      0.307      -0.007       0.023
# C(SchoolYear)[T.2023]     0.0071      0.008      0.921      0.358      -0.008       0.022
# C(Sex)[T.Male]            0.0091      0.002      5.397      0.000       0.006       0.012
# ==============================================================================
# Omnibus:                      183.570   Durbin-Watson:                   1.702
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1035.478
# Skew:                           1.449   Prob(JB):                    1.41e-225
# Kurtosis:                       9.306   Cond. No.                         45.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# A key finding is that obesity rates went up a lot in 2020 (5.59% higher than usual), with smaller but noticeable increases in 2004 and 2021. Additionally, males tend to have higher obesity rates than females (0.91% more). This suggests that certain years (especially 2020) and gender differences are important in understanding obesity trends.

# %%
df['NonObese'] = df['ValidCounts'] - df['EpiObese']
print(df[['ValidCounts', 'EpiObese', 'NonObese']].head())
# Out:
#    ValidCounts  EpiObese  NonObese
# 0          418        28       390
# 1          411        42       369
# 2          979       106       873
# 3          936       114       822
# 4         1764       155      1609

# %%
model_binom = smf.glm(
    formula="EpiObese ~ C(SchoolYear) + C(Sex)",
    data=df,
    family=sm.families.Binomial(),
    weights=df['ValidCounts']
).fit()
print(model_binom.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:               EpiObese   No. Observations:                  516
# Model:                            GLM   Df Residuals:                      492
# Model Family:                Binomial   Df Model:                           23
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                   -inf
# Date:                Fri, 28 Feb 2025   Deviance:                   7.4942e+06
# Time:                        14:50:22   Pearson chi2:                 1.22e+23
# No. Iterations:                     2   Pseudo R-squ. (CS):                nan
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept              9.667e+17   2.39e+07   4.04e+10      0.000    9.67e+17    9.67e+17
# C(SchoolYear)[T.2002]  2.677e+17   3.36e+07   7.98e+09      0.000    2.68e+17    2.68e+17
# C(SchoolYear)[T.2003] -7.206e+16   3.06e+07  -2.35e+09      0.000   -7.21e+16   -7.21e+16
# C(SchoolYear)[T.2004]  1.057e+17   2.97e+07   3.55e+09      0.000    1.06e+17    1.06e+17
# C(SchoolYear)[T.2005]  1.039e+17   2.91e+07   3.57e+09      0.000    1.04e+17    1.04e+17
# C(SchoolYear)[T.2006] -1.032e+17   2.85e+07  -3.62e+09      0.000   -1.03e+17   -1.03e+17
# C(SchoolYear)[T.2007] -1.571e+17   2.81e+07  -5.59e+09      0.000   -1.57e+17   -1.57e+17
# C(SchoolYear)[T.2008] -1.424e+17   2.74e+07   -5.2e+09      0.000   -1.42e+17   -1.42e+17
# C(SchoolYear)[T.2009]  1.016e+17   2.71e+07   3.74e+09      0.000    1.02e+17    1.02e+17
# C(SchoolYear)[T.2010] -7.889e+16   2.69e+07  -2.93e+09      0.000   -7.89e+16   -7.89e+16
# C(SchoolYear)[T.2011]  2.048e+17   2.69e+07   7.61e+09      0.000    2.05e+17    2.05e+17
# C(SchoolYear)[T.2012]  1.892e+17   2.69e+07   7.03e+09      0.000    1.89e+17    1.89e+17
# C(SchoolYear)[T.2013]  3.161e+17   2.69e+07   1.17e+10      0.000    3.16e+17    3.16e+17
# C(SchoolYear)[T.2014]  2.615e+17   2.69e+07   9.72e+09      0.000    2.62e+17    2.62e+17
# C(SchoolYear)[T.2015]  2.507e+17   2.69e+07   9.32e+09      0.000    2.51e+17    2.51e+17
# C(SchoolYear)[T.2016]  2.919e+17   2.69e+07   1.09e+10      0.000    2.92e+17    2.92e+17
# C(SchoolYear)[T.2017]   2.62e+17   2.69e+07   9.74e+09      0.000    2.62e+17    2.62e+17
# C(SchoolYear)[T.2018]  7.648e+16   2.69e+07   2.84e+09      0.000    7.65e+16    7.65e+16
# C(SchoolYear)[T.2019] -2.993e+17   2.81e+07  -1.07e+10      0.000   -2.99e+17   -2.99e+17
# C(SchoolYear)[T.2020]  5.274e+17   2.97e+07   1.77e+10      0.000    5.27e+17    5.27e+17
# C(SchoolYear)[T.2021]  5.286e+17   2.69e+07   1.96e+10      0.000    5.29e+17    5.29e+17
# C(SchoolYear)[T.2022]  2.297e+17   2.69e+07   8.54e+09      0.000     2.3e+17     2.3e+17
# C(SchoolYear)[T.2023]   1.51e+17   2.69e+07   5.61e+09      0.000    1.51e+17    1.51e+17
# C(Sex)[T.Male]         1.359e+17   5.91e+06    2.3e+10      0.000    1.36e+17    1.36e+17
# =========================================================================================

# %%
fitted_vals = model_linear.fittedvalues
residuals = model_linear.resid
plt.figure(figsize=(8, 5))
sns.residplot(x=fitted_vals, y=residuals, lowess=True,
              line_kws={'color': 'red', 'lw': 1, 'alpha': 0.8})
plt.xlabel('Fitted values')
plt.ylabel('Residuals')
plt.title('Residuals vs Fitted Values')
plt.show()

# %% [markdown]
# Residuals lie along the 45-degree line, they are approximately normally distributed. Deviations might indicate skewness or heavy tails.

# %%
influence = model_linear.get_influence()
standardized_residuals = influence.resid_studentized_internal
plt.figure(figsize=(8, 5))
sns.scatterplot(x=fitted_vals, y=np.sqrt(np.abs(standardized_residuals)))
sns.regplot(x=fitted_vals, y=np.sqrt(np.abs(standardized_residuals)),
            scatter=False, lowess=True, line_kws={'color': 'red', 'lw': 1})
plt.xlabel('Fitted values')
plt.ylabel('Sqrt(|Standardized Residuals|)')
plt.title('Scale-Location Plot')
plt.show()

# %% [markdown]
# A horizontal line suggests constant variance. An upward or downward trend indicates non-constant variance (heteroscedasticity)

# %%
leverage = influence.hat_matrix_diag
cooks = influence.cooks_distance[0]
plt.figure(figsize=(8, 6))
sns.scatterplot(x=leverage, y=standardized_residuals)
sns.regplot(x=leverage, y=standardized_residuals, scatter=False, lowess=True,
            line_kws={'color': 'red', 'lw': 1})
plt.xlabel('Leverage')
plt.ylabel('Standardized Residuals')
plt.title('Residuals vs Leverage')
plt.show()

# %%
plt.figure(figsize=(10, 4))
plt.stem(np.arange(len(cooks)), cooks, markerfmt=",")
plt.xlabel('Observation Index')
plt.ylabel("Cook's Distance")
plt.title("Cook's Distance for Each Observation")
plt.show()

# %% [markdown]
# Points with high leverage and large standardized residuals (or high Cook’s distance) may be influential and warrant further investigation.
